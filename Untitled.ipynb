# %%
run plotter.py

# %%
p = Plotter()

# %%
# %matplotlib inline

# %%
p.plotDf(p.currencies[0])

# %%
for c in p.currencies: p.plotDf(c)

# %%
basicDF = p.load(p.currencies[0])

# %%
for c in p.currencies[1:]:
    basicDF[c] = p.load(c)[c]

# %%
basicDF.plot(y=p.currencies)
